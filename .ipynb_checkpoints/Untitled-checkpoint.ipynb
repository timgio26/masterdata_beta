# %%
import requests
import json
import pandas as pd

# %%
r=requests.post('https://integration.forstok.com/api/v2/auth?id=grace.permatasari@nutrifood.co.id&secret_key=FB9R2wVY3VuPmuu6mjS6PX&type=seller')
token=r.json()['data']['token']

# %%
url = "https://accounts.forstok.com/api/v2/orders.json"

payload = {'user_id': 'grace.permatasari@nutrifood.co.id', 'auth_type': 'jwt','created_after':'2022-09-18 00:00:00'}
headers = {'Content-Type': 'application/json',
           "Authorization": f"Bearer {token}"}


response = requests.request("GET", url, headers=headers, params=payload)

# print(response.json())
ordlist=[i['id'] for i in response.json()['orders']]
print(len(ordlist))
# Out:
# 433

# %%
resdf=pd.DataFrame(index=[])

for order in ordlist:
    print(order)
    url = f"https://accounts.forstok.com/api/v1/orders/{order}.json"
    payload = {'user_id': 'grace.permatasari@nutrifood.co.id', 'auth_type': 'jwt'}
    headers = {'Content-Type': 'application/json',"Authorization": f"Bearer {token}"}
    response = requests.request("GET", url, headers=headers, params=payload)
    
    df=pd.DataFrame(response.json()['item_lines'])
    if len(response.json()['item_lines'])>0:
        df['Qty. Invoiced']=df.groupby('sku').cumcount()+1
        if len(df.index)>1:
            print('lebih dr 1 pcs')
        df=df.drop_duplicates('sku',keep='last').rename(columns={'name':'product_name'})
        df['order_id']=order

        for i in response.json().items():
            # print(i[0])
            if i[0] in ['local_name','status','store_name','channel','ordered_at','subtotal','discount_amount','shipping_price','total_price']:
                df[i[0]]=f"{i[1]}"
                # display(df[[i[0]]])
            elif i[0]=='address':
                df['address_1']=f"{response.json()['address']['address_1']}"
                for data in ['city','country','name','phone','postal_code']:
                    df[f'{data}']=f"{response.json()['address'][f'{data}']}"
            # print()
        df=df[['order_id','id','local_name','status','store_name','channel',
            'ordered_at','product_name','sku','price',
            'sale_price','Qty. Invoiced','subtotal','total_price',
            'discount_amount','shipping_provider','shipping_price','total_price',
            'name','phone','address_1','city','country','postal_code']]
        resdf=resdf.append(df).reset_index(drop=True)
    else:
        print('cancel no item')

# %%
resdf[resdf['order_id'].isin([125529454])]#[['sku','price','sale_price','Qty. Invoiced','subtotal','total_price']]
resdf['order_id'].nunique()
# Out:
# 431

# %%
data_sku=requests.get('https://tatanama.pythonanywhere.com/apinew')
data_sku=pd.DataFrame(data_sku.json())

# %%
data_sku
# Out:
#         ID            SKU   Brand  \
# 0        1     2300551155   L-Men
# 1        2     2303054155   L-Men
# 2        3     2303056180   L-Men
# 3        4     2304036151   L-Men
# 4        5     2304051151   L-Men
# ...    ...            ...     ...
# 2893  3099  (E)1101694318  W'dank
# 2894  3100      PN115G267  Bundle
# 2895  3101      PN108G267  Bundle
# 2896  3102      PN108G267  Bundle
# 2897  3103      PN107G267  Bundle
#
#                                             Nama_Produk Price_List_NFI  \
# 0                 L-Men Whey Daily Dark Chocolate 250gr          57720
# 1                  L-Men Whey Advanced Cappuccino 250gr          88800
# 2               L-Men Whey Advanced Choco Vanilla 500gr         166500
# 3                          L-Men Gain Mass Banana 225gr          66600
# 4                       L-Men Gain Mass Chocolate 225gr          66600
# ...                                                 ...            ...
# 2893        Near ED - Lokalate Kopi Andaliman 10 Sachet          13200
# 2894  Free Tas - NutriSari Gula Asem 40 Sachet - Min...          43290
# 2895  Free Tas - NutriSari Summer Package 40 Sachet ...          43290
# 2896  Free Tas - NutriSari Summer Package 40 Sachet ...          43290
# 2897  Free Tas - NutriSari Local Package 40 Sachet -...          43290
#
#      Harga_Display Harga_Cost Harga_Organik  Kode    Alias_SKU_1  ...  \
# 0            69000      57720             0    L1         FS MBW  ...
# 1           102100      88800             0    L2         FS MBS  ...
# 2           191500     166500             0    L3  2303056180(2)  ...
# 3            76600      66600             0    L4                 ...
# 4            76600      66600             0    L5                 ...
# ...            ...        ...           ...   ...            ...  ...
# 2893         17500      13200             0  E105           None  ...
# 2894         62000      43290             0  None           None  ...
# 2895         62000      43290             0  None           None  ...
# 2896         62000      43290             0  None           None  ...
# 2897         62000      43290             0  None           None  ...
#
#      Volume_4 Berat_5 Volume_5 Berat_6 Volume_6 Berat_7 Volume_7  Active  \
# 0                                                                 Active
# 1                                                                 Active
# 2                                                                 Active
# 3                                                                 Active
# 4                                                                 Active
# ...       ...     ...      ...     ...      ...     ...      ...     ...
# 2893     None    None     None    None     None    None     None    None
# 2894                                                                None
# 2895                                                                None
# 2896                                                                None
# 2897                                                                None
#
#      Alias_Nama_8 Alias_SKU_8
# 0            None        None
# 1            None        None
# 2            None        None
# 3            None        None
# 4            None        None
# ...           ...         ...
# 2893         None        None
# 2894         None        None
# 2895         None        None
# 2896         None        None
# 2897         None        None
#
# [2898 rows x 111 columns]
