# %%
import requests

# %%
r=requests.post('https://integration.forstok.com/api/v2/auth?id=grace.permatasari@nutrifood.co.id&secret_key=FB9R2wVY3VuPmuu6mjS6PX&type=seller')

# %%
token=r.json()['data']['token']#.load()

# %%
token
# Out:
# 'eyJhbGciOiJIUzI1NiJ9.eyJpZCI6ImdyYWNlLnBlcm1hdGFzYXJpQG51dHJpZm9vZC5jby5pZCIsImV4cF9hdCI6IjIwMjItMTAtMTcgMDk6MjE6MjIgKzA3MDAiLCJhdXRoX3R5cGUiOiJzZWxsZXIifQ.pAJDS2drdAWeoeYBLcayj-rzYjxuNr48yhgRKy891Y4'

# %%
import requests
import json

url = "https://accounts.forstok.com/api/v2/orders.json"

payload = {'user_id': 'grace.permatasari@nutrifood.co.id', 'auth_type': 'jwt','created_after':'2022-09-16 00:00:00'}
headers = {'Content-Type': 'application/json',
           "Authorization": f"Bearer {token}"}


response = requests.request("GET", url, headers=headers, params=payload)

print(response.json())

# %%
# pd.DataFrame(response.json()['orders'])['id']
ordlist=[i['id'] for i in response.json()['orders']]#.keys()

# %%
import requests
import json
resdf=pd.DataFrame(index=[0])
for order in ordlist:
    print(order)
    url = f"https://accounts.forstok.com/api/v1/orders/{order}.json"
    payload = {'user_id': 'grace.permatasari@nutrifood.co.id', 'auth_type': 'jwt'}
    headers = {'Content-Type': 'application/json',"Authorization": f"Bearer {token}"}
    response = requests.request("GET", url, headers=headers, params=payload)
    
    df=pd.DataFrame(response.json()['item_lines'])
    df['Qty. Invoiced']=df.groupby('sku').cumcount()+1
    df=df.drop_duplicates('sku',keep='last').rename(columns={'name':'product_name'})

    for i in response.json().items():
        # print(i[0])
        if i[0] in ['local_name','status','store_name','channel','ordered_at','subtotal','discount_amount','shipping_price','total_price']:
            df[i[0]]=f"{i[1]}"
            # display(df[[i[0]]])
        elif i[0]=='address':
            df['address_1']=f"{response.json()['address']['address_1']}"
            for data in ['city','country','name','phone','postal_code']:
                df[f'{data}']=f"{response.json()['address'][f'{data}']}"
        # print()
    df[['local_name','status','store_name','channel',
        'ordered_at','product_name','sku','price',
        'sale_price','Qty. Invoiced','subtotal','total_price',
        'discount_amount','shipping_provider','shipping_price','total_price',
        'name','phone','address_1','city','country','postal_code']]
    resdf=resdf.append(df)
# Out:
# 125520795
# 125520744
# 125520718
# 125520768
# 125520770
# 125520676
# 125520663
# 125520662
# 125520648
# 125520643
# 125520636
# 125520635
# 125520630
# 125520608
# 125520620
# 125520596
# 125520595
# 125520619
# 125520563
# 125520769
# 125520523
# 125520618
# 125520617
# 125520616
# 125520503
# 125520615
# 125520485
# 125520614
# 125520454
# 125520430
# 125520423
# 125520414
# 125520613
# 125520405
# 125520612
# 125520380
# 125520373
# 125520401
# 125520399
# 125520340
# 125520355
# 125520322
# 125520309
# 125520308
# 125520290
# 125520398
# 125520303
# 125520295
# 125520283
# 125520259
# 125520396
# 125520250
# 125520395
# 125512187
# 125512005
# 125512203
# 125512186
# 125512185
# 125511961
# 125512184
# 125512183
# 125511921
# 125511894
# 125512182
# 125511875
# 125511876
# 125511874
# 125511793
# 125511873
# 125511872
# 125511871
# 125511870
# 125511705
# 125511697
# 125511712
# 125511688
# 125511780
# 125511781
# 125511693
# 125511695
# 125511690
# 125511869
# 125511678
# 125511868
# 125511656
# 125511651
# 125511633
# 125511867
# 125511866
# 125511622
# 125511601
# 125511603
# 125511865
# 125511864
# 125511569
# 125511565
# 125511546
# 125511524
# 125511564
# 125511492
# 125511563
# 125511562
# 125511561
# 125511560
# 125511437
# 125511434
# 125511414
# 125511386
# 125511559
# 125511558
# 125511398
# 125511422
# 125511328
# 125511339
# 125511557
# 125511279
# 125511283
# 125511555
# 125511556
# 125511251
# 125511249
# 125511253
# 125511239
# 125511225
# 125511212
# 125511248
# 125511186
# 125511196
# 125511247
# 125511246
# 125511131
# 125511143
# 125511135
# 125511245
# 125511141
# 125511120
# 125511114
# 125511088
# 125511243
# 125511242
# 125511084
# 125511396
# 125511395
# 125511043
# 125511244
# 125511005
# 125510984
# 125510964
# 125510994
# 125510987
# 125510993
# 125511002
# 125510881
# 125510860
# 125510803
# 125510992
# 125510986
# 125511001
# 125510822
# 125510789
# 125510799
# 125510794
# 125510787
# 125510683
# 125510675
# 125510686
# 125510668
# 125510659
# 125510649
# 125510617
# 125510624
# 125510616
# 125510590
# 125510543
# 125510578
# 125510636
# 125510559
# 125510553
# 125510527
# 125510529
# 125510699
# 125510700
# 125510698
# 125510451
# 125510489

# %%
# for order in response.json()['orders']:
#     print(order['id'])#['id']
# https://accounts.forstok.com/api/v1/orders/118339622.json?user_id={{user_id}}&auth_type=jwt

import requests
import json

url = "https://accounts.forstok.com/api/v1/orders/125510994.json"
payload = {'user_id': 'grace.permatasari@nutrifood.co.id', 'auth_type': 'jwt'}
headers = {'Content-Type': 'application/json',"Authorization": f"Bearer {token}"}
response = requests.request("GET", url, headers=headers, params=payload)

print(response.json())

# %%
len(response.json().keys())#['status']

df=pd.DataFrame(response.json()['item_lines'])
df['Qty. Invoiced']=df.groupby('sku').cumcount()+1
df=df.drop_duplicates('sku',keep='last').rename(columns={'name':'product_name'})

for i in response.json().items():
    # print(i[0])
    if i[0] in ['local_name','status','store_name','channel','ordered_at','subtotal','discount_amount','shipping_price','total_price']:
        df[i[0]]=f"{i[1]}"
        # display(df[[i[0]]])
    elif i[0]=='address':
        df['address_1']=f"{response.json()['address']['address_1']}"
        for data in ['city','country','name','phone','postal_code']:
            df[f'{data}']=f"{response.json()['address'][f'{data}']}"
    # print()
df[['local_name','status','store_name','channel',
    'ordered_at','product_name','sku','price',
    'sale_price','Qty. Invoiced','subtotal','total_price',
    'discount_amount','shipping_provider','shipping_price','total_price',
    'name','phone','address_1','city','country','postal_code']]
# Out:
#                     local_name   status store_name    channel  \
# 1  INV/20220917/MPL/2662396522  Printed  Tokopedia  tokopedia
#
#             ordered_at                                product_name  \
# 1  2022-09-17 09:17:07  L-Men Hi Protein Whey Daily Dark Chocolate
#
#           sku  price sale_price  Qty. Invoiced subtotal total_price  \
# 1  2300551155  57000       None              2   114000      114000
#
#   discount_amount shipping_provider shipping_price total_price         name  \
# 1               0             Swift           5700      114000  junari hadi
#
#            phone                                          address_1  \
# 1  *********8989  jln H.naipin , Kec. Mustika Jaya, Kota Bks, Ja...
#
#           city    country postal_code
# 1  Kota Bekasi  Indonesia       17158

# %%
df=pd.DataFrame(response.json()['item_lines'])
df['Qty. Invoiced']=df.groupby('sku').cumcount()+1
df=df.drop_duplicates('sku',keep='last').rename(columns={'name':'product_name'})

# %%
df
# Out:
#           id  local_id         sku  \
# 1  112398290  22351954  2300551155
#
#                                  product_name variant_name  variant_id  \
# 1  L-Men Hi Protein Whey Daily Dark Chocolate         None     6251392
#
#   variant_sku  price sale_price total_price  voucher_amount voucher_code  \
# 1  2300551155  57000       None      114000               0
#
#    voucher_seller  tax_price  fulfill_by_channel shipping_provider  \
# 1             0.0          0                True             Swift
#
#   shipping_provider_type tracking_number  note internal_note bundle_info  \
# 1                  Swift                  None          None          []
#
#    Qty. Invoiced   status    channel                   local_name store_name  \
# 1              2  Printed  tokopedia  INV/20220917/MPL/2662396522  Tokopedia
#
#                                            address_1         city    country  \
# 1  jln H.naipin , Kec. Mustika Jaya, Kota Bks, Ja...  Kota Bekasi  Indonesia
#
#           name          phone postal_code           ordered_at shipping_price  \
# 1  junari hadi  *********8989       17158  2022-09-17 09:17:07           5700
#
#   subtotal discount_amount
# 1   114000               0

# %%
response.json()
# Out:
# {'id': 125510994,
#  'status': 'Printed',
#  'channel': 'tokopedia',
#  'channel_id': 15,
#  'local_id': '1355397636',
#  'local_name': 'INV/20220917/MPL/2662396522',
#  'store_name': 'Tokopedia',
#  'store_id': 1266,
#  'profile_id': 82,
#  'address': {'address_1': 'jln H.naipin , Kec. Mustika Jaya, Kota Bks, Jawa Barat, 17158 [Tokopedia Note: jln raya mustika jaya,tuguh bambu claster the layla] block c4',
#   'address_2': '',
#   'city': 'Kota Bekasi',
#   'country': 'Indonesia',
#   'name': 'junari hadi',
#   'phone': '*********8989',
#   'postal_code': '17158',
#   'province': 'Jawa Barat',
#   'province_code': None,
#   'sub_district': '',
#   'district': None,
#   'coordinate': None},
#  'customer_info': {'id': 9619712,
#   'name': 'junari hadi',
#   'email': '',
#   'customer_since': '2019-05-06 19:06:51'},
#  'dropshipper_info': None,
#  'ordered_at': '2022-09-17 09:17:07',
#  'created_at': '2022-09-17 09:20:25',
#  'updated_at': '2022-09-17 09:36:18',
#  'item_lines': [{'id': 112398290,
#    'local_id': '22351954',
#    'sku': '2300551155',
#    'name': 'L-Men Hi Protein Whey Daily Dark Chocolate',
#    'variant_name': None,
#    'variant_id': 6251392,
#    'variant_sku': '2300551155',
#    'price': 57000,
#    'sale_price': None,
#    'total_price': 57000,
#    'voucher_amount': 0,
#    'voucher_code': '',
#    'voucher_seller': 0.0,
#    'tax_price': 0,
#    'fulfill_by_channel': True,
#    'shipping_provider': 'Swift',
#    'shipping_provider_type': 'Swift',
#    'tracking_number': '',
#    'note': None,
#    'internal_note': None,
#    'bundle_info': []},
#   {'id': 112398290,
#    'local_id': '22351954',
#    'sku': '2300551155',
#    'name': 'L-Men Hi Protein Whey Daily Dark Chocolate',
#    'variant_name': None,
#    'variant_id': 6251392,
#    'variant_sku': '2300551155',
#    'price': 57000,
#    'sale_price': None,
#    'total_price': 57000,
#    'voucher_amount': 0,
#    'voucher_code': '',
#    'voucher_seller': 0.0,
#    'tax_price': 0,
#    'fulfill_by_channel': True,
#    'shipping_provider': 'Swift',
#    'shipping_provider_type': 'Swift',
#    'tracking_number': '',
#    'note': None,
#    'internal_note': None,
#    'bundle_info': []}],
#  'payment': {'payment_method': 'GoPay Coins', 'status': 'Payment Verified'},
#  'shipping_price': 5700,
#  'disc_shipping_seller': 0,
#  'disc_shipping_platform': 0,
#  'shipping_courier': {'awb': '',
#   'document_path': 'https://accounts.forstok.com/api/v1/documents.pdf?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJvcmRlcl9pZHMiOjEyNTUxMDk5NCwidHlwZSI6InNoaXBwaW5nX2xhYmVscyIsImVtYWlsIjoiZ3JhY2UucGVybWF0YXNhcmlAbnV0cmlmb29kLmNvLmlkIiwicHJvZmlsZV9pZCI6ODJ9.pnrDf9LkRC1b2GinhJHz9DPFVCIOzzqjzrJj8FeyGeg',
#   'booking_code': None,
#   'delivery_type': 'PICKUP',
#   'channel_docs_path': None,
#   'logistic_destination_code': None},
#  'shipping_provider': 'Swift',
#  'shipping_provider_type': 'Swift',
#  'shipping_description': None,
#  'subtotal': 114000,
#  'channel_rebate': 0,
#  'cashless': True,
#  'discount_amount': 0,
#  'total_price': 114000,
#  'voucher_code': None,
#  'voucher_seller': 0,
#  'insurance_fee': 0,
#  'discount_reason': None,
#  'tax_price': 0,
#  'warehouse_id': 1338,
#  'cod': False,
#  'delivery_type': None,
#  'warehouse_code': '',
#  'note': None,
#  'internal_note': '{"bundle_detail":null,"promo_order_detail":{"order_id":1355397636,"total_cashback":0,"total_discount":5700,"total_discount_product":0,"total_discount_shipping":5700,"total_discount_details":[{"amount":5700,"type":"discount_shipping"}],"summary_promo":[{"name":"Bebas Ongkir Dilayani Tokopedia !","is_coupon":false,"show_cashback_amount":true,"show_discount_amount":true,"cashback_amount":0,"cashback_points":0,"cashback_details":[],"type":"discount","discount_amount":5700,"invoice_desc":"","discount_details":[{"amount":5700,"type":"discount_shipping","budget_details":[{"budget_type":1,"benefit_amount":5700,"actual_benefit_amount":5700},{"budget_type":2,"benefit_amount":0,"actual_benefit_amount":0},{"budget_type":3,"benefit_amount":0,"actual_benefit_amount":0}]}]}]}}',
#  'returns': []}
